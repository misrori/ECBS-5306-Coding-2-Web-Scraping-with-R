# %%
from selenium import webdriver
import time

driver = webdriver.Chrome('/home/mihaly/R_codes/ECBS-5306-Coding-2-Web-Scraping-with-R/week-6/chromedriver')
driver.get("https://www.google.com/")
print('sleep')
time.sleep(10)
driver.close()
# Out:
# sleep

# %%
# hasznaltauto demo

from selenium import webdriver
import time

driver = webdriver.Chrome('/home/mihaly/R_codes/ECBS-5306-Coding-2-Web-Scraping-with-R/week-6/chromedriver')
driver.get("https://www.hasznaltauto.hu/")
print('sleep')
time.sleep(10)
driver.find_element_by_css_selector(".MuiButton-disableElevation").click()
time.sleep(10)

for i in range(1,5):
    driver.find_element_by_css_selector(".haicon-uj-jnyil-kicsi").click()
    page = driver.page_source
    my_file = open('data_html/page_'+str(i)+'.html', 'w')
    my_file.write(page)
    my_file.close()
    
    time.sleep(10)
driver.close()
# Out:
# sleep

# %%
# economist

from selenium import webdriver
import time

driver = webdriver.Chrome('/home/mihaly/R_codes/ECBS-5306-Coding-2-Web-Scraping-with-R/week-6/chromedriver')
driver.get("https://www.economist.com/leaders/")
time.sleep(5)
for i in range(1,5):
    driver.execute_script("window.scrollTo(0, 1000)")
    driver.find_element_by_css_selector(".pagination__pagedirection--next").click()
    page = driver.page_source
    my_file = open('data_html/econ_page_'+str(i)+'.html', 'w')
    my_file.write(page)
    my_file.close()
    
    time.sleep(5)
driver.close()
# Out:
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# <ipython-input-1-3c95040e5f59> in <module>()
#       4 import time
#       5
# ----> 6 driver = webdriver.Chrome('/home/mihaly/R_codes/web_scraping/class_5/chromedriver')
#       7 driver.get("https://www.economist.com/leaders/")
#       8 time.sleep(5)
#
# /home/mihaly/anaconda3/lib/python3.5/site-packages/selenium/webdriver/chrome/webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, keep_alive)
#      79                     remote_server_addr=self.service.service_url,
#      80                     keep_alive=keep_alive),
# ---> 81                 desired_capabilities=desired_capabilities)
#      82         except Exception:
#      83             self.quit()
#
# ...

# %%
#linkedin
from selenium import webdriver
import time
from selenium.webdriver.common.keys import Keys

start_url = "https://www.linkedin.com"
driver = webdriver.Chrome('/home/mihaly/R_codes/ECBS-5306-Coding-2-Web-Scraping-with-R/week-6/chromedriver')

driver.get(start_url)
time.sleep(10)
driver.find_element_by_name("session_key").send_keys("ormraat.pte@gmail.com")
#driver.find_element_by_name("session_password").send_keys("")

time.sleep(30)

driver.find_element_by_css_selector("a+ button").click()

# %%
import time
from pyvirtualdisplay import Display
display = Display(visible=0, size=(1920, 1080)).start()
from selenium import webdriver
from selenium.webdriver import ActionChains
driver = webdriver.Chrome('/home/mihaly/R_codes/ECBS-5306-Coding-2-Web-Scraping-with-R/week-6/chromedriver')


driver.get("https://www.bbc.com/")
time.sleep(15)

t_names = driver.page_source

file = open("/home/mihaly/R_codes/ECBS-5306-Coding-2-Web-Scraping-with-R/week-6/bbc.html",'w',encoding='utf-8')
file.write(t_names)
file.close()
driver.close()
display.stop()
# Out:
# <Display cmd_param=['Xvfb', '-br', '-nolisten', 'tcp', '-screen', '0', '1920x1080x24', ':1028'] cmd=['Xvfb', '-br', '-nolisten', 'tcp', '-screen', '0', '1920x1080x24', ':1028'] oserror=None return_code=0 stdout="" stderr="" timeout_happened=False>

# %%
# mnb
from selenium import webdriver
import time
import pandas as pd
atmnevek = []
atmcimek =[]
idk = []

driver = webdriver.Chrome('/home/mihaly/R_codes/ECBS-5306-Coding-2-Web-Scraping-with-R/week-6/chromedriver')
driver.get("https://fiokesatmkereso.mnb.hu/web/index.html")
time.sleep(20)




for i in range(1,30):
    nevek =driver.find_elements_by_css_selector("div.list-item-data-title")
    cimek = driver.find_elements_by_css_selector(".list-item-data-title+ .list-item-data-details")
    m_idk = driver.find_elements_by_css_selector(".list-item")
    
    hosz = len(cimek)
    for i in range(0,len(cimek)):
        atmnevek.append(nevek[i].text)
        atmcimek.append(cimek[i].text)
        idk.append(m_idk[i].get_attribute('id'))
        

    driver.find_element_by_css_selector("#pager-control-next img").click()
    time.sleep(1)
    
driver.quit()

df = pd.DataFrame({'cimek':atmcimek,'atmnevek':atmnevek, 'id':idk})

df.to_csv('all_data_text.csv')
df
# Out:
#                             atmnevek                                   cimek  \
# 0               OTP Bank Nyrt. - ATM          Szigony utca 12, 1083 Budapest
# 1               OTP Bank Nyrt. - ATM   Bókay János utca 36-42, 1083 Budapest
# 2    Euronet Banktechikai Kft. - ATM          Baross utca 111, 1083 Budapest
# 3    Euronet Banktechikai Kft. - ATM     Thaly Kálmán utca 43, 1096 Budapest
# 4    Euronet Banktechikai Kft. - ATM     Thaly Kálmán utca 46, 1096 Budapest
# 5    Euronet Banktechikai Kft. - ATM          Corvin sétány 4, 1082 Budapest
# 6               K&H Bank Zrt. - Fiók         Futó utca 47-53., 1082 Budapest
# 7                K&H Bank Zrt. - ATM          Futó utca 47-53, 1082 Budapest
# 8              OTP Bank Nyrt. - Fiók         Tinódi utca 9-11, 1095 Budapest
# 9      Erste Bank Hungary Zrt. - ATM          Futó utca 37-43, 1082 Budapest
# 10              OTP Bank Nyrt. - ATM               Orczy út 1, 1083 Budapest
# ...
